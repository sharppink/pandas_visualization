# %%
import pandas as pd

# %%
data = pd.read_csv('top20_countries.csv')
data
# Out:
#                    Country  Agricultural Land( %)  Land Area(Km2)  \
# 0              Afghanistan                   58.1          652230
# 1                  Albania                   43.1           28748
# 2                  Algeria                   17.4         2381741
# 3                   Angola                   47.5         1246700
# 4                Argentina                   54.3         2780400
# 5                  Armenia                   58.9           29743
# 6                Australia                   48.2         7741220
# 7                  Austria                   32.4           83871
# 8               Azerbaijan                   57.7           86600
# 9              The Bahamas                    1.4           13880
# 10                 Bahrain                   11.1             765
# 11              Bangladesh                   70.6          148460
# 12                Barbados                   23.3             430
# 13                 Belarus                   42.0          207600
# 14                 Belgium                   44.6           30528
# 15                  Belize                    7.0           22966
# 16                   Benin                   33.3          112622
# 17                  Bhutan                   13.6           38394
# 18                 Bolivia                   34.8         1098581
# 19  Bosnia and Herzegovina                   43.1           51197
#
#     Armed Forces size  Forested Area (%)            GDP  Infant mortality  \
# 0              323000                2.1    19101353833              47.9
# 1                9000               28.1    15278077447               7.8
# 2              317000                0.8   169988236398              20.1
# 3              117000               46.3    94635415870              51.6
# 4              105000                9.8   449663446954               8.8
# 5               49000               11.7    13672802158              11.0
# 6               58000               16.3  1392680589329               3.1
# 7               21000               46.9   446314739528               2.9
# 8               82000               14.1    39207000000              19.2
# 9                1000               51.4    12827000000               8.3
# 10              19000                0.8    38574069149               6.1
# 11             221000               11.0   302571254131              25.1
# 12               1000               14.7     5209000000              11.3
# 13             155000               42.6    63080457023               2.6
# 14              32000               22.6   529606710418               2.9
# 15               2000               59.7     1879613600              11.2
# 16              12000               37.8    14390709095              60.5
# 17               6000               72.5     2446674101              24.8
# 18              71000               50.3    40895322865              21.8
# 19              11000               42.7    20047848435               5.0
#
#     Life expectancy  Population  Population: Labor force participation (%)  \
# 0              64.5    38041754                                       48.9
# 1              78.5     2854191                                       55.7
# 2              76.7    43053054                                       41.2
# 3              60.8    31825295                                       77.5
# 4              76.5    44938712                                       61.3
# 5              74.9     2957731                                       55.6
# 6              82.7    25766605                                       65.5
# 7              81.6     8877067                                       60.7
# 8              72.9    10023318                                       66.5
# 9              73.8      389482                                       74.6
# 10             77.2     1501635                                       73.4
# 11             72.3   167310838                                       59.0
# 12             79.1      287025                                       65.2
# 13             74.2     9466856                                       64.1
# 14             81.6    11484055                                       53.6
# 15             74.5      390353                                       65.1
# 16             61.5    11801151                                       70.9
# 17             71.5      727145                                       66.7
# 18             71.2    11513100                                       71.8
# 19             77.3     3301000                                       46.4
#
#     Unemployment rate  Urban_population
# 0               11.12           9797273
# 1               12.33           1747593
# 2               11.70          31510100
# 3                6.89          21061025
# 4                9.79          41339571
# 5               16.99           1869848
# 6                5.27          21844756
# 7                4.67           5194416
# 8                5.51           5616165
# 9               10.36            323784
# 10               0.71           1467109
# 11               4.19          60987417
# 12              10.33             89431
# 13               4.59           7482982
# 14               5.59          11259082
# 15               6.41            179039
# 16               2.23           5648149
# 17               2.34            317538
# 18               3.50           8033035
# 19              18.42           1605144

# %%
from sklearn.manifold import MDS
import matplotlib.pyplot as plt

# %%
numerical_data = data.select_dtypes(include=[float, int])

# %%
mds = MDS(n_components=2, random_state=42)
mds_transformed = mds.fit_transform(numerical_data)

# %%
mds_df = pd.DataFrame(mds_transformed, columns=['Dimension 1', 'Dimension 2'])

plt.figure(figsize=(10, 8))
plt.scatter(mds_df['Dimension 1'], mds_df['Dimension 2'])

for i, country in enumerate(data['Country']):
    plt.text(mds_df.loc[i, 'Dimension 1'], mds_df.loc[i, 'Dimension 2'], country)

plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('MDS')
plt.grid(True)
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import pairwise_distances

# %%
iris = load_iris()
data = iris.data
labels = iris.target
feature_names = iris.feature_names

# %%
df = pd.DataFrame(data, columns=feature_names)

# %%
mds = MDS(n_components=2, random_state=42, dissimilarity='euclidean')
mds_transformed = mds.fit_transform(df)

# %%
original_distances = pairwise_distances(data)
low_dim_distances = pairwise_distances(mds_transformed)

stress = ((original_distances - low_dim_distances) ** 2).sum() / (original_distances ** 2).sum()
stress = stress ** 0.5

print(f'Stress 값: {stress:.4f}')
# Out:
# Stress 값: 0.0405

# %%
mds_df = pd.DataFrame(mds_transformed, columns=['Dimension 1', 'Dimension 2'])
mds_df['label'] = labels

plt.figure(figsize=(10, 8))
scatter = plt.scatter(mds_df['Dimension 1'], mds_df['Dimension 2'], c=mds_df['label'], cmap='viridis')

legend = plt.legend(*scatter.legend_elements(), title="Classes")
plt.gca().add_artist(legend)

plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('MDS of Iris Dataset')
plt.grid(True)
plt.show()
