# %%
import pandas as pd

# %%
data = pd.read_excel('통합.xlsx')
data
# Out:
#             날짜  지역    주택구입부담지수  기준금리    거래량      인구수    물가지수
# 0   2021-01-01  서울  163.970000  0.50  12275  9657969  100.86
# 1   2021-02-01  서울  166.200000  0.50  12707  9648606  101.33
# 2   2021-03-01  서울  168.430000  0.50  11122  9598484  101.57
# 3   2021-04-01  서울  169.870000  0.50  11873  9588711  101.68
# 4   2021-05-01  서울  172.900000  0.50  13145  9575355  101.74
# ..         ...  ..         ...   ...    ...      ...     ...
# 811 2024-08-01  제주   72.300000  3.50    532   671540  114.25
# 812 2024-09-01  제주   73.827162  3.50    485   671064  114.09
# 813 2024-10-01  제주   76.002123  3.25    614   670837  114.34
# 814 2024-11-01  제주   75.600000  3.00    557   670632  114.11
# 815 2024-12-01  제주   75.197877  3.00    534   670368  114.37
#
# [816 rows x 7 columns]

# %%
data['지역'].unique()
# Out:
# array(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
data1 = pd.read_excel('capstone/아파트 매매 실거래가격지수_31233316.xlsx')
data1
# Out:
#           계정항목  2021/01  2021/02  2021/03  2021/04  2021/05  2021/06  2021/07  \
# 0           전국    123.6    125.8    127.5    129.2    131.5    134.5    137.8
# 1           서울    167.6    169.9    170.8    171.9    175.4    179.7    183.7
# 2          도심권    157.7    159.0    158.9    161.5    163.6    169.0    170.9
# 3          동북권    177.0    180.5    182.0    183.6    187.1    191.2    195.9
# 4          동남권    162.7    164.1    164.1    164.8    167.8    171.8    176.1
# 5          서북권    164.6    166.9    166.1    168.9    169.0    174.8    178.3
# 6          서남권    165.1    167.2    168.2    169.3    173.7    177.0    180.3
# 7          수도권    141.1    144.6    147.2    149.6    153.5    158.3    163.3
# 8           지방    108.4    109.7    110.6    111.6    112.7    114.2    115.9
# 9           부산    112.2    113.8    114.0    115.8    117.6    119.7    122.2
# 10          대구    127.1    129.0    130.4    130.6    131.2    131.8    132.8
# ...

# %%
data2 = pd.read_excel('capstone/주택건설인허가실적_31233443.xlsx')
data2
# Out:
#       계정항목  2021/01  2021/02  2021/03  2021/04  2021/05  2021/06  2021/07  \
# 0       전국    26183    59830   105184   149793   186743   230761   277354
# 1       서울     2695     9599    16290    26397    30915    37194    46041
# 2       인천     1327     2029     2430     2855     3546     3962     5119
# 3       경기     8141    19110    34085    49040    59683    75883    91980
# 4       부산     2256     3193     4330     5809     8479     9891    13936
# 5       대구      308     1743     6997     8740     9515    10227    12215
# 6       광주       57      495      930     1176     1802     2034     3548
# 7       대전      884     3446     7026     7196     8461     8596     8898
# 8       울산     2200     2251     3606     4026     4159     4561     4863
# 9       세종       15       38       75      118     1537     1946     2000
# 10      강원      393      768     1276     2719     4942     7096     9509
# 11      충북     3138     4038     4652     5115     5469     7652     8100
# ...

# %%
df_melted = data1.melt(id_vars='계정항목', var_name='날짜', value_name='실거래가격지수')
df_melted
# Out:
#             계정항목       날짜  실거래가격지수
# 0             전국  2021/01    123.6
# 1             서울  2021/01    167.6
# 2            도심권  2021/01    157.7
# 3            동북권  2021/01    177.0
# 4            동남권  2021/01    162.7
# ...          ...      ...      ...
# 1339          경남  2024/12     94.7
# 1340          제주  2024/12    107.0
# 1341      광역시 1)  2024/12    111.5
# 1342    지방광역시 2)  2024/12    108.8
# 1343      지방도 3)  2024/12    103.3
#
# [1344 rows x 3 columns]

# %%
df_melted['날짜'] = pd.to_datetime(df_melted['날짜'] + '/01', format='%Y/%m/%d')
df_melted
# Out:
#             계정항목         날짜  실거래가격지수
# 0             전국 2021-01-01    123.6
# 1             서울 2021-01-01    167.6
# 2            도심권 2021-01-01    157.7
# 3            동북권 2021-01-01    177.0
# 4            동남권 2021-01-01    162.7
# ...          ...        ...      ...
# 1339          경남 2024-12-01     94.7
# 1340          제주 2024-12-01    107.0
# 1341      광역시 1) 2024-12-01    111.5
# 1342    지방광역시 2) 2024-12-01    108.8
# 1343      지방도 3) 2024-12-01    103.3
#
# [1344 rows x 3 columns]

# %%
df_melted.rename(columns={'계정항목': '지역'}, inplace=True)

# %%
df_melted = df_melted.sort_values(by=['지역', '날짜']).reset_index(drop=True)

# %%
df_melted['지역'].unique()
# Out:
# array(['    도심권', '    동남권', '    동북권', '    서남권', '    서북권', '  강원',
#        '  경기', '  경남', '  경북', '  광역시 1)', '  광주', '  대구', '  대전', '  부산',
#        '  서울', '  세종', '  수도권', '  울산', '  인천', '  전남', '  전북', '  제주',
#        '  지방', '  지방광역시 2)', '  지방도 3)', '  충남', '  충북', '전국'],
#       dtype=object)

# %%
valid_regions = data['지역'].unique()
valid_regions
# Out:
# array(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
df_melted.columns = df_melted.columns.str.strip()

# %%
df_melted = df_melted[df_melted['지역'].isin(valid_regions)].copy()
df_melted
# Out:
#       지역         날짜  실거래가격지수
# 240   강원 2021-01-01     95.7
# 241   강원 2021-02-01     96.8
# 242   강원 2021-03-01     98.2
# 243   강원 2021-04-01     99.4
# 244   강원 2021-05-01    100.1
# ...   ..        ...      ...
# 1291  충북 2024-08-01    109.4
# 1292  충북 2024-09-01    109.8
# 1293  충북 2024-10-01    109.5
# 1294  충북 2024-11-01    109.0
# 1295  충북 2024-12-01    108.0
#
# [816 rows x 3 columns]

# %%
df_melted['지역'] = df_melted['지역'].str.strip()
df_melted['지역'].unique()
# Out:
# array(['도심권', '동남권', '동북권', '서남권', '서북권', '강원', '경기', '경남', '경북',
#        '광역시 1)', '광주', '대구', '대전', '부산', '서울', '세종', '수도권', '울산', '인천',
#        '전남', '전북', '제주', '지방', '지방광역시 2)', '지방도 3)', '충남', '충북', '전국'],
#       dtype=object)

# %%
df_melted
# Out:
#       지역         날짜  실거래가격지수
# 240   강원 2021-01-01     95.7
# 241   강원 2021-02-01     96.8
# 242   강원 2021-03-01     98.2
# 243   강원 2021-04-01     99.4
# 244   강원 2021-05-01    100.1
# ...   ..        ...      ...
# 1291  충북 2024-08-01    109.4
# 1292  충북 2024-09-01    109.8
# 1293  충북 2024-10-01    109.5
# 1294  충북 2024-11-01    109.0
# 1295  충북 2024-12-01    108.0
#
# [816 rows x 3 columns]

# %%
df_merged = pd.merge(
    df_merged,
    df_melted,
    on=['날짜', '지역'],
    how='left'  # 필요한 경우 'inner'로도 가능
)
df_merged
# Out:
#             날짜  지역    주택구입부담지수  기준금리    거래량      인구수    물가지수  주택인허가실적  실거래가격지수
# 0   2021-01-01  서울  163.970000  0.50  12275  9657969  100.86     2695    167.6
# 1   2021-02-01  서울  166.200000  0.50  12707  9648606  101.33     9599    169.9
# 2   2021-03-01  서울  168.430000  0.50  11122  9598484  101.57    16290    170.8
# 3   2021-04-01  서울  169.870000  0.50  11873  9588711  101.68    26397    171.9
# 4   2021-05-01  서울  172.900000  0.50  13145  9575355  101.74    30915    175.4
# ..         ...  ..         ...   ...    ...      ...     ...      ...      ...
# 811 2024-08-01  제주   72.300000  3.50    532   671540  114.25     2028    109.4
# 812 2024-09-01  제주   73.827162  3.50    485   671064  114.09     2254    109.7
# 813 2024-10-01  제주   76.002123  3.25    614   670837  114.34     2456    111.4
# 814 2024-11-01  제주   75.600000  3.00    557   670632  114.11     2557    109.7
# 815 2024-12-01  제주   75.197877  3.00    534   670368  114.37     3264    107.0
#
# [816 rows x 9 columns]

# %%
df_merged
# Out:
#             날짜  지역    주택구입부담지수  기준금리    거래량      인구수    물가지수  주택인허가실적  실거래가격지수
# 0   2021-01-01  서울  163.970000  0.50  12275  9657969  100.86     2695    167.6
# 1   2021-02-01  서울  166.200000  0.50  12707  9648606  101.33     9599    169.9
# 2   2021-03-01  서울  168.430000  0.50  11122  9598484  101.57    16290    170.8
# 3   2021-04-01  서울  169.870000  0.50  11873  9588711  101.68    26397    171.9
# 4   2021-05-01  서울  172.900000  0.50  13145  9575355  101.74    30915    175.4
# ..         ...  ..         ...   ...    ...      ...     ...      ...      ...
# 811 2024-08-01  제주   72.300000  3.50    532   671540  114.25     2028    109.4
# 812 2024-09-01  제주   73.827162  3.50    485   671064  114.09     2254    109.7
# 813 2024-10-01  제주   76.002123  3.25    614   670837  114.34     2456    111.4
# 814 2024-11-01  제주   75.600000  3.00    557   670632  114.11     2557    109.7
# 815 2024-12-01  제주   75.197877  3.00    534   670368  114.37     3264    107.0
#
# [816 rows x 9 columns]

# %%
df_merged.to_excel('통합_1.xlsx', index=False)
