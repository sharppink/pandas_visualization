# %%
import pandas as pd

# %%
data = pd.read_excel('death_2023.xlsx')
data
# Out:
#                                  사망 원인     전국     서울     부산     대구     인천  \
# 0                                총 사망자  689.2  551.1  799.2  697.8  614.8
# 1                     특정 감염성 및 기생충성 질환   37.1   31.1   39.3   37.7   29.2
# 2                                  신생물  170.3  149.1  202.2  169.7  162.5
# 3     혈액 및 조혈기관 질환과 면역메커니즘을 침범하는 특정 장애    1.7    1.2    2.5    2.0    1.4
# 4                      내분비, 영양 및 대사 질환   24.8   21.2   34.7   21.1   23.2
# 5                           정신 및 행동 장애    8.2    5.6   14.9    8.5   10.3
# 6                             신경계통의 질환   37.1   30.6   44.3   27.7     27
# 7                           귀 및 유돌의 질환    0.0      -      -    0.1      -
# 8                             순환계통의 질환  132.1  102.4  177.4  129.2    116
# 9                             호흡계통의 질환   89.1   65.9   98.2  103.7   73.3
# 10                            소화계통의 질환   27.3   20.3   31.5   26.8   24.8
# 11                       피부 및 피하조직의 질환    1.0    0.6    1.1    1.0      1
# ...
