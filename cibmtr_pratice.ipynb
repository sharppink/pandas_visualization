# %%
import pandas as pd
import numpy as np
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index

# %%
data = pd.read_csv('equity-post-HCT-survival-predictions/train.csv')

# %%
df = data[['efs_time', 'efs']]

# %%
time = df['efs_time']
event = df['efs']

# %%
cph = CoxPHFitter()
cph.fit(df, duration_col='efs_time', event_col='efs')
# Out:
# <lifelines.CoxPHFitter: fitted with 28800 total observations, 13268 right-censored observations>

# %%
c_index = concordance_index(time, -cph.predict_partial_hazard(df), event)
print(f'C-index: {c_index}')
# Out:
# C-index: 0.5

# %%
data
# Out:
#           ID                                          dri_score psych_disturb  \
# 0          0                     N/A - non-malignant indication            No
# 1          1                                       Intermediate            No
# 2          2                     N/A - non-malignant indication            No
# 3          3                                               High            No
# 4          4                                               High            No
# ...      ...                                                ...           ...
# 28795  28795  Intermediate - TED AML case <missing cytogenetics           NaN
# 28796  28796                                               High            No
# 28797  28797                                   TBD cytogenetics           NaN
# 28798  28798                     N/A - non-malignant indication            No
# 28799  28799                                    N/A - pediatric            No
#
# ...
